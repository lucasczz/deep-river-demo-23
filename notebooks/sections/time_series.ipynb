# %% [markdown]
# ## To what extent does architecture influence model performance?
# ### From now-casting to forecasting in online deep learning.

# %%
from river import datasets, metrics, preprocessing
import pandas as pd

# %%
data = list(datasets.Bikes().take(10_000))
x = pd.DataFrame([x for x, _ in data])
x
# Out:
#                   moment              station  clouds description  humidity  \
# 0    2016-04-01 00:00:07  metro-canal-du-midi      75  light rain        81
# 1    2016-04-01 00:00:16     place-des-carmes      75  light rain        81
# 2    2016-04-01 00:00:35     place-des-carmes      75  light rain        81
# 3    2016-04-01 00:04:50       place-esquirol      75  light rain        81
# 4    2016-04-01 00:05:29       place-esquirol      75  light rain        81
# ...                  ...                  ...     ...         ...       ...
# 9995 2016-04-10 19:00:14     place-des-carmes       0   clear sky        52
# 9996 2016-04-10 19:01:32  metro-canal-du-midi       0   clear sky        52
# 9997 2016-04-10 19:01:34       place-esquirol       0   clear sky        52
# 9998 2016-04-10 19:02:09       place-esquirol       0   clear sky        52
# 9999 2016-04-10 19:03:02    place-jeanne-darc       0   clear sky        52
#
#       pressure  temperature  wind
# ...

# %%
data[7]
# Out:
# ({'moment': datetime.datetime(2016, 4, 1, 0, 9, 25),
#   'station': 'place-jeanne-darc',
#   'clouds': 75,
#   'description': 'light rain',
#   'humidity': 81,
#   'pressure': 1017.0,
#   'temperature': 6.54,
#   'wind': 9.3},
#  11)
